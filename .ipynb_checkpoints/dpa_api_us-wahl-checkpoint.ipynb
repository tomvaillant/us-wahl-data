# %%
import requests
import pandas as pd
import json
import numpy as np
import os
from datetime import datetime

base_url = "https://digitalwires.dpa-newslab.com/iaeystP2ZVzUx1PBhd5Tr2LODbdSavCV/aufschaltung/au-clC0AH31tVaf0fbHu2/apigate-electionsdata/f-wmGZTrfmonUjD1FR"
us_election_id = "us-2024"
results = "results?election=us-2024&stage=sim"

url = f"{base_url}/{results}"


response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print("Successfully received data:")
else:
    print(f"Request failed with status code: {response.status_code}")
    print(f"Response content: {response.text}")
    
data
# Out:
# Successfully received data:
# {'election': {'id': 'us-2024',
#   'name': [{'language': 'en-US', 'name': 'United States elections, 2024'}],
#   'date': {'start_date': '2024-11-05T00:00:00.000Z',
#    'end_date': '2024-11-05T00:00:00.000Z'},
#   'contest': [{'id': '20982bc9-fbbe-47d2-9445-ba3901b04e64',
#     'office_id': 'us-pres',
#     'round': 1,
#     'number_of_votes': 1,
#     'number_of_seats': 538,
#     'legislative_period': 47,
#     'date': {'start_date': '2024-11-05T00:00:00.000Z',
#      'end_date': '2024-11-05T00:00:00.000Z'},
#     'type_of_election': 'general',
#     'results_overall': {'constituency_id': 'a7a5cca5-96e5-47e5-b270-4a7b37604618',
#      'latest': {'status_date': '2024-10-16T14:35:00.000Z',
#       'type': 'preliminary',
#       'source': {'name': 'CNN'},
#       'additional_information': {'turnout': None,
#        'turnout_predicted': None,
#        'voters': None,
#        'votes': None,
#        'votes_valid': None,
#        'votes_invalid': None},
#       'results': [{'target': 'candidates',
#         'target_id': '99c2245e-08d5-4c5c-87b9-c959516eb8b8',
#         'percent': [{'type': 'first_vote',
#           'value': {'type': 'absolute',
#            'min': None,
#            'max': None,
#            'absolute': 49.798}}],
#         'votes': [],
#         'seats': {'type': 'absolute',
#          'min': None,
#          'max': None,
#          'absolute': 262}},
#        {'target': 'candidates',
#         'target_id': '5144ec75-57d2-4970-a9a2-ffb79fa2dc06',
#         'percent': [{'type': 'first_vote',
#           'value': {'type': 'absolute',
#            'min': None,
#            'max': None,
#            'absolute': 48.595}}],
#         'votes': [],
#         'seats': {'type': 'absolute',
#          'min': None,
#          'max': None,
#          'absolute': 216}}],
#       'counting_progress': {'counting_type': 'states_called',
#        'unit': 'absolute',
#        'current': 46,
#        'max': 51}},
#      'past_election': {'status_date': '2021-05-05T08:44:00.000Z',
#       'type': 'past_election',
#       'source': {'name': 'CNN'},
#       'additional_information': {'turnout': None,
#        'turnout_predicted': None,
#        'voters': None,
#        'votes': [],
#        'votes_valid': [],
#        'votes_invalid': []},
#       'results': [{'target': 'candidates',
#         'target_id': '99c2245e-08d5-4c5c-87b9-c959516eb8b8',
#         'percent': [{'type': 'first_vote',
#           'value': {'type': 'absolute',
#            'min': None,
#            'max': None,
#            'absolute': 51.3}}],
#         'votes': [{'type': 'first_vote', 'value': 81284666}],
#         'seats': {'type': 'absolute',
#          'min': None,
#          'max': None,
#          'absolute': 306}},
#        {'target': 'candidates',
#         'target_id': '5144ec75-57d2-4970-a9a2-ffb79fa2dc06',
#         'percent': [{'type': 'first_vote',
#           'value': {'type': 'absolute',
#            'min': None,
#            'max': None,
#            'absolute': 46.9}}],
#         'votes': [{'type': 'first_vote', 'value': 74224319}],
#         'seats': {'type': 'absolute',
#          'min': None,
#          'max': None,
#          'absolute': 232}}]},
#      'counting_progress': {'counting_type': 'states_called',
#       'unit': 'absolute',
#       'current': 46,
#       'max': 51}},
#     'results_per_constituency': [{'constituency_id': '58cf982c-a3d8-41b1-8bd5-3ce728dc0548',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': 'c9d7d5fc-865c-4578-ae54-12d9ba85eb46',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.387}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'ea8b862a-5bf1-40b5-aa22-3920d4c623da',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 60.612}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}}]},
#       'past_election': {'status_date': '2020-12-11T10:23:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'c9d7d5fc-865c-4578-ae54-12d9ba85eb46',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 38.6}}],
#          'votes': [{'type': 'first_vote', 'value': 199922}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'ea8b862a-5bf1-40b5-aa22-3920d4c623da',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 59.4}}],
#          'votes': [{'type': 'first_vote', 'value': 307486}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': 'df799bd9-09d5-4199-9aab-ac0d011509a9',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '40c43826-c735-4a5a-a18e-3be2c4e4e62a',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.797}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '148997cf-1a93-4bf6-a73e-781e65bd152f',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 60.202}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 7}}]},
#       'past_election': {'status_date': '2021-02-08T00:01:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '148997cf-1a93-4bf6-a73e-781e65bd152f',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 59.3}}],
#          'votes': [{'type': 'first_vote', 'value': 1080831}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 7}},
#         {'target': 'candidates',
#          'target_id': '40c43826-c735-4a5a-a18e-3be2c4e4e62a',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.2}}],
#          'votes': [{'type': 'first_vote', 'value': 714717}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': 'ca61f513-643f-45ba-aeff-9a9a2c5c6347',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '0331106c-568c-466d-b7bc-c9fee87ac4c3',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 69.789}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': '03c968c2-5957-47e4-9aa7-cfec42a2e9d0',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 30.21}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2021-01-27T08:11:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '0331106c-568c-466d-b7bc-c9fee87ac4c3',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 68.6}}],
#          'votes': [{'type': 'first_vote', 'value': 545382}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 5}},
#         {'target': 'candidates',
#          'target_id': '03c968c2-5957-47e4-9aa7-cfec42a2e9d0',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 29.7}}],
#          'votes': [{'type': 'first_vote', 'value': 235984}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '58783e04-6e56-448b-84b5-55d1cb509222',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '56911498-a59c-490a-b71e-8040e6095921',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 53.717}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': 'dc34237d-ba81-4b44-aac9-f0b88bced98a',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 46.282}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2021-03-08T09:35:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '56911498-a59c-490a-b71e-8040e6095921',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 52.7}}],
#          'votes': [{'type': 'first_vote', 'value': 424937}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': 'dc34237d-ba81-4b44-aac9-f0b88bced98a',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 45.4}}],
#          'votes': [{'type': 'first_vote', 'value': 365660}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '81158d8a-2221-4438-bbac-8af1ecb6147d',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '4953d774-8532-48f9-b7b6-f72d0727abf4',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 65.843}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': '9c617f2f-98bb-4dcc-92a9-7560d3f857d4',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 34.156}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2020-03-06T09:39:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '4953d774-8532-48f9-b7b6-f72d0727abf4',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 63.8}}],
#          'votes': [{'type': 'first_vote', 'value': 554119}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': '9c617f2f-98bb-4dcc-92a9-7560d3f857d4',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 33.1}}],
#          'votes': [{'type': 'first_vote', 'value': 287021}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '3c9d5b5b-59ec-4155-bb2a-b8b0396ac191',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '026b7d1a-bdc6-4051-82f1-75f1c5874454',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 59.591}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}},
#         {'target': 'candidates',
#          'target_id': '7e66db64-9d82-4c99-9d91-f505f27d3c4a',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 40.408}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2021-04-28T10:30:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '7e66db64-9d82-4c99-9d91-f505f27d3c4a',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.8}}],
#          'votes': [{'type': 'first_vote', 'value': 200603}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '026b7d1a-bdc6-4051-82f1-75f1c5874454',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58.7}}],
#          'votes': [{'type': 'first_vote', 'value': 296268}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': 'e6c9d211-93f8-4f92-a602-30fe61ada53c',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': 'a00e2e8c-e1e6-4d69-9f8a-76ba42c87f2f',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 40.55}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'df84edd0-d392-4d50-9735-99d7ee537b62',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 59.449}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 8}}]},
#       'past_election': {'status_date': '2021-01-26T09:47:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'a00e2e8c-e1e6-4d69-9f8a-76ba42c87f2f',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.9}}],
#          'votes': [{'type': 'first_vote', 'value': 856034}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'df84edd0-d392-4d50-9735-99d7ee537b62',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58.5}}],
#          'votes': [{'type': 'first_vote', 'value': 1255776}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 8}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '3235b34e-2295-40b2-9abf-2cdb0c6c7e33',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'trend',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '1b00dd30-37e9-4404-b23d-c4b576cd0913',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 55.23}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'fde8aa28-4dd7-4ef7-b43a-6508eb4ef18d',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 44.769}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2020-12-02T08:51:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '1b00dd30-37e9-4404-b23d-c4b576cd0913',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 52.8}}],
#          'votes': [{'type': 'first_vote', 'value': 189951}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}},
#         {'target': 'candidates',
#          'target_id': 'fde8aa28-4dd7-4ef7-b43a-6508eb4ef18d',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 42.8}}],
#          'votes': [{'type': 'first_vote', 'value': 153778}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 60,
#        'max': 100}},
#      {'constituency_id': '56e10156-ebc7-4f97-ba07-8e5c4d328303',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '70045f36-39df-45ec-bc52-05abda5e9214',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58.373}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 6}},
#         {'target': 'candidates',
#          'target_id': 'ddc85d44-37a2-4c07-a0d6-9b18bb8bc897',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 41.626}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2021-04-29T01:45:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'ddc85d44-37a2-4c07-a0d6-9b18bb8bc897',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 41}}],
#          'votes': [{'type': 'first_vote', 'value': 539398}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '70045f36-39df-45ec-bc52-05abda5e9214',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 57.5}}],
#          'votes': [{'type': 'first_vote', 'value': 756764}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 6}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '7fa60682-6c92-4ce9-a698-a7c134325e4e',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '3dc11084-d415-4f4d-848b-ddbc773578ea',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 63.45}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}},
#         {'target': 'candidates',
#          'target_id': 'e105b2d4-c1c1-48b8-80f7-fc00b4dadec3',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 36.549}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2020-11-24T07:21:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'e105b2d4-c1c1-48b8-80f7-fc00b4dadec3',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 35.6}}],
#          'votes': [{'type': 'first_vote', 'value': 150471}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '3dc11084-d415-4f4d-848b-ddbc773578ea',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 61.8}}],
#          'votes': [{'type': 'first_vote', 'value': 261043}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '620225eb-2b33-419b-b8f1-0d3c3abadb81',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '1ac5b1ef-34c0-4d54-945a-88520eb8c63d',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 32.921}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '51404234-39a7-405e-9968-fac74306be94',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 67.078}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 10}}]},
#       'past_election': {'status_date': '2021-03-06T05:14:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '1ac5b1ef-34c0-4d54-945a-88520eb8c63d',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 32.1}}],
#          'votes': [{'type': 'first_vote', 'value': 976414}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '51404234-39a7-405e-9968-fac74306be94',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 65.4}}],
#          'votes': [{'type': 'first_vote', 'value': 1985023}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 10}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '76dfbad0-8935-4dc3-9081-cc8a6d81d2bf',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': 'c7802c9b-de24-494c-acb9-ecd9418b28c2',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 47.162}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'c10a50a7-0146-4d98-9d66-a89c071cfebb',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 52.837}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 40}}]},
#       'past_election': {'status_date': '2021-02-22T02:14:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'c7802c9b-de24-494c-acb9-ecd9418b28c2',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 46.5}}],
#          'votes': [{'type': 'first_vote', 'value': 5259126}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'c10a50a7-0146-4d98-9d66-a89c071cfebb',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 52.1}}],
#          'votes': [{'type': 'first_vote', 'value': 5890347}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 38}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': 'e5ee9b9c-0b3e-4a5f-8ff1-ae59f7933b3d',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '1d26e6bb-d277-44bc-b17f-31c6ee93b10e',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 61.764}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 28}},
#         {'target': 'candidates',
#          'target_id': '06b59d50-08a9-4942-a60e-68a7f0f48fae',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 38.235}}],
#          'votes': [],
#          'seats': {}}]},
#       'past_election': {'status_date': '2021-04-02T08:00:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '1d26e6bb-d277-44bc-b17f-31c6ee93b10e',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 60.9}}],
#          'votes': [{'type': 'first_vote', 'value': 5244886}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 29}},
#         {'target': 'candidates',
#          'target_id': '06b59d50-08a9-4942-a60e-68a7f0f48fae',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 37.7}}],
#          'votes': [{'type': 'first_vote', 'value': 3251997}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '7ca51a7b-c813-4e48-92bb-8d677754dd0b',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '97c34685-d53f-4ce5-b06d-91d25fa8fccd',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 38.12}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'b2ff44e0-02d6-40e9-8c29-e22ccaf16b46',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 61.879}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 11}}]},
#       'past_election': {'status_date': '2021-03-06T05:20:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'b2ff44e0-02d6-40e9-8c29-e22ccaf16b46',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 60.7}}],
#          'votes': [{'type': 'first_vote', 'value': 1852475}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 11}},
#         {'target': 'candidates',
#          'target_id': '97c34685-d53f-4ce5-b06d-91d25fa8fccd',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 37.4}}],
#          'votes': [{'type': 'first_vote', 'value': 1143711}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '342c4793-f7db-4252-980b-6edd699e96aa',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '1885db58-7a8a-421d-b82e-bd00d401b51b',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 41.581}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '931e585d-0d83-4a9f-9c64-8edd44a00480',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58.418}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}}]},
#       'past_election': {'status_date': '2021-03-06T05:15:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '1885db58-7a8a-421d-b82e-bd00d401b51b',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 40.5}}],
#          'votes': [{'type': 'first_vote', 'value': 244786}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '931e585d-0d83-4a9f-9c64-8edd44a00480',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 56.9}}],
#          'votes': [{'type': 'first_vote', 'value': 343602}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '611fcdc2-9fe1-4737-b3db-3b6c7fee164a',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': 'dd60a570-84ad-4e1f-a472-7fde94ee7598',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 43.998}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 1}},
#         {'target': 'candidates',
#          'target_id': 'db4eca71-f3dc-4218-86ec-59de8a5f861f',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 53.097}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'past_election': {'status_date': '2021-02-24T00:33:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'dd60a570-84ad-4e1f-a472-7fde94ee7598',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 44}}],
#          'votes': [{'type': 'first_vote', 'value': 360737}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 1}},
#         {'target': 'candidates',
#          'target_id': 'db4eca71-f3dc-4218-86ec-59de8a5f861f',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 53.1}}],
#          'votes': [{'type': 'first_vote', 'value': 435072}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': 'd00265c7-6d58-4871-8a14-6944537d04b6',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '5b4da257-b6b3-4b4b-8aeb-51b87c024f2b',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 5.535}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '5f4fe962-0f71-490c-8af2-78b3ce047c4c',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 94.464}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'past_election': {'status_date': '2020-12-02T09:00:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '5b4da257-b6b3-4b4b-8aeb-51b87c024f2b',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 5.4}}],
#          'votes': [{'type': 'first_vote', 'value': 18586}],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': '5f4fe962-0f71-490c-8af2-78b3ce047c4c',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 92.1}}],
#          'votes': [{'type': 'first_vote', 'value': 317323}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 3}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '20663e5a-dcfa-461c-962d-574e10956f46',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': 'e597910c-cf12-42a3-8735-b5d76fc94ba1',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 40.084}}],
#          'votes': [],
#          'seats': {}},
#         {'target': 'candidates',
#          'target_id': 'c6b03dc1-5ba7-4ccb-8401-12b12b7b69c1',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 59.915}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 12}}]},
#       'past_election': {'status_date': '2020-12-08T09:45:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': 'c6b03dc1-5ba7-4ccb-8401-12b12b7b69c1',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58}}],
#          'votes': [{'type': 'first_vote', 'value': 2369612}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 12}},
#         {'target': 'candidates',
#          'target_id': 'e597910c-cf12-42a3-8735-b5d76fc94ba1',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 38.8}}],
#          'votes': [{'type': 'first_vote', 'value': 1584651}],
#          'seats': {}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
#      {'constituency_id': '9c67194f-4c10-4195-88b7-6093a3c02e14',
#       'latest': {'status_date': '2024-10-16T14:36:00.000Z',
#        'type': 'preliminary',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': None,
#         'votes_valid': None,
#         'votes_invalid': None},
#        'results': [{'target': 'candidates',
#          'target_id': '99277764-06ed-455c-99bb-f04f658ecf42',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58.203}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': '242cf177-4286-493f-800e-80f4c2efe124',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.199}}],
#          'votes': [],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 1}}]},
#       'past_election': {'status_date': '2021-01-15T02:47:00.000Z',
#        'type': 'past_election',
#        'source': {'name': 'CNN'},
#        'additional_information': {'turnout': None,
#         'turnout_predicted': None,
#         'voters': None,
#         'votes': [],
#         'votes_valid': [],
#         'votes_invalid': []},
#        'results': [{'target': 'candidates',
#          'target_id': '99277764-06ed-455c-99bb-f04f658ecf42',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 58.2}}],
#          'votes': [{'type': 'first_vote', 'value': 556846}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 4}},
#         {'target': 'candidates',
#          'target_id': '242cf177-4286-493f-800e-80f4c2efe124',
#          'percent': [{'type': 'first_vote',
#            'value': {'type': 'absolute',
#             'min': None,
#             'max': None,
#             'absolute': 39.2}}],
#          'votes': [{'type': 'first_vote', 'value': 374583}],
#          'seats': {'type': 'absolute',
#           'min': None,
#           'max': None,
#           'absolute': 1}}]},
#       'counting_progress': {'counting_type': None,
#        'unit': 'percent',
#        'current': 80,
#        'max': 100}},
# ...
#   {'id': '314a1c8a-48b7-4516-9d5b-cf8e485d0ea4',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '89b9a6de-fc7e-4c3b-8971-14c548abe484'},
#   {'id': 'a68616d6-fc79-4207-ba93-b703f110b8c2',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '89b9a6de-fc7e-4c3b-8971-14c548abe484'},
#   {'id': '99277764-06ed-455c-99bb-f04f658ecf42',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '9c67194f-4c10-4195-88b7-6093a3c02e14'},
#   {'id': '242cf177-4286-493f-800e-80f4c2efe124',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '9c67194f-4c10-4195-88b7-6093a3c02e14'},
#   {'id': '1885db58-7a8a-421d-b82e-bd00d401b51b',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '342c4793-f7db-4252-980b-6edd699e96aa'},
#   {'id': '931e585d-0d83-4a9f-9c64-8edd44a00480',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '342c4793-f7db-4252-980b-6edd699e96aa'},
#   {'id': '70f1abab-933f-4383-b4be-67080319f78e',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '2b437c24-fd42-4f26-8dce-0c33ff0ce651'},
#   {'id': '777f81e1-7fba-4cb2-ba43-75e31f059ee1',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '2b437c24-fd42-4f26-8dce-0c33ff0ce651'},
#   {'id': '18cc03c3-bfb0-475c-a05e-eae08456dea6',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '8bc0752f-a89e-4e1f-bbac-3115cfa01168'},
#   {'id': '51d2eb1e-a093-49f6-ab24-5452d42aa604',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '8bc0752f-a89e-4e1f-bbac-3115cfa01168'},
#   {'id': '6f2fcfa1-767b-4b97-b7af-d1a906770b71',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '53e375fb-d5cc-4387-a656-fafd18d8788c'},
#   {'id': '3b51153a-7554-4bfe-8ca6-2b2b0fa0b593',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '53e375fb-d5cc-4387-a656-fafd18d8788c'},
#   {'id': '4953d774-8532-48f9-b7b6-f72d0727abf4',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '81158d8a-2221-4438-bbac-8af1ecb6147d'},
#   {'id': '9c617f2f-98bb-4dcc-92a9-7560d3f857d4',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '81158d8a-2221-4438-bbac-8af1ecb6147d'},
#   {'id': '87394c69-270a-4bf5-815f-3f8e7c0c5bae',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '14dc6538-8285-4e0a-8c03-c46bebf9de9b'},
#   {'id': 'd329a40f-eb21-4e98-9820-20843f61a8aa',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '14dc6538-8285-4e0a-8c03-c46bebf9de9b'},
#   {'id': 'e79c80a2-9a50-44a5-a9c9-24c5eb95917c',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'c64a4d18-d0eb-4dfa-8520-b5f93d773056'},
#   {'id': 'faef6d85-fb8a-4d02-86c2-379aa6b68d56',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'c64a4d18-d0eb-4dfa-8520-b5f93d773056'},
#   {'id': 'dece9dcc-feb3-44e1-94c0-d88a9fc4a2b4',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '80b7e001-d242-4211-b3ef-5772e0a8466e'},
#   {'id': 'f271b680-e9a3-407a-9a62-fbd7840b35c2',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '80b7e001-d242-4211-b3ef-5772e0a8466e'},
#   {'id': '714c7b2a-0510-4515-af64-c9a20827e589',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'b92df48b-2c6d-465b-a59f-811be46ff750'},
#   {'id': '2cea8215-9bcc-45fa-8e44-7089ba4db17a',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'b92df48b-2c6d-465b-a59f-811be46ff750'},
#   {'id': '97c34685-d53f-4ce5-b06d-91d25fa8fccd',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '7ca51a7b-c813-4e48-92bb-8d677754dd0b'},
#   {'id': 'b2ff44e0-02d6-40e9-8c29-e22ccaf16b46',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '7ca51a7b-c813-4e48-92bb-8d677754dd0b'},
#   {'id': 'cb8e86c4-2683-4e72-93b0-c25c5d386ade',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'b09bab02-80e4-4ed6-958d-38ccb6156f8e'},
#   {'id': '9caf6b79-f184-45e5-b250-5bcf4284ee99',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'b09bab02-80e4-4ed6-958d-38ccb6156f8e'},
#   {'id': '93334b59-8f18-4c22-8fa2-393a315ecba4',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'f8f7e900-df10-42d9-8726-4ea9fe63779a'},
#   {'id': '9663166f-11a0-4bd0-beb8-824363140dfc',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'f8f7e900-df10-42d9-8726-4ea9fe63779a'},
#   {'id': '99c2245e-08d5-4c5c-87b9-c959516eb8b8',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'a7a5cca5-96e5-47e5-b270-4a7b37604618'},
#   {'id': '5144ec75-57d2-4970-a9a2-ffb79fa2dc06',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'a7a5cca5-96e5-47e5-b270-4a7b37604618'},
#   {'id': '2f682ce0-543e-4a79-b5a8-862fc908b64d',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '85012372-c138-4ae1-93e9-544eafc92db9'},
#   {'id': '132b2d14-fa75-4b1d-917b-572ebc74c201',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '85012372-c138-4ae1-93e9-544eafc92db9'},
#   {'id': '34c1b324-1908-4d4e-9053-ba69915eb785',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'ecf04f39-4731-4f21-bcc9-48a857c9e51d'},
#   {'id': 'a05c88e1-2646-496a-b02a-f61b39270319',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'ecf04f39-4731-4f21-bcc9-48a857c9e51d'},
#   {'id': '1d26e6bb-d277-44bc-b17f-31c6ee93b10e',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'e5ee9b9c-0b3e-4a5f-8ff1-ae59f7933b3d'},
#   {'id': '06b59d50-08a9-4942-a60e-68a7f0f48fae',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'e5ee9b9c-0b3e-4a5f-8ff1-ae59f7933b3d'},
#   {'id': '9f7adb78-0041-4348-826b-1c590aa214c2',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '47aeea33-5b4c-48c1-b071-578efc7905eb'},
#   {'id': '752e7d5a-636c-4310-ab9e-1f0aac19ab7f',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '47aeea33-5b4c-48c1-b071-578efc7905eb'},
#   {'id': '56911498-a59c-490a-b71e-8040e6095921',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '58783e04-6e56-448b-84b5-55d1cb509222'},
#   {'id': 'dc34237d-ba81-4b44-aac9-f0b88bced98a',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '58783e04-6e56-448b-84b5-55d1cb509222'},
#   {'id': '23cfe74c-ec81-4060-a230-d960a4463153',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '4e5c29d4-8d24-4b90-a6ef-e7b743a330b7'},
#   {'id': '561e2545-3968-488d-8155-9c0461e752b7',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '4e5c29d4-8d24-4b90-a6ef-e7b743a330b7'},
#   {'id': 'dd60a570-84ad-4e1f-a472-7fde94ee7598',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '611fcdc2-9fe1-4737-b3db-3b6c7fee164a'},
#   {'id': 'db4eca71-f3dc-4218-86ec-59de8a5f861f',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '611fcdc2-9fe1-4737-b3db-3b6c7fee164a'},
#   {'id': '06fd07ff-14ca-4ad3-8eff-65a928551e85',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '87e3088d-9138-4db2-879e-d60b913178d3'},
#   {'id': '6ab686ff-7dc7-4b23-9bb7-de1ffc4ef382',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '87e3088d-9138-4db2-879e-d60b913178d3'},
#   {'id': 'ce91765f-c771-473f-bf62-9c90986c7e27',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '62500c24-b5b6-4413-996b-38e1a7579106'},
#   {'id': 'e425d66c-fd97-465e-8e7e-b526a6bbcd15',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '62500c24-b5b6-4413-996b-38e1a7579106'},
#   {'id': 'b802a5b4-98dc-43b3-b682-5232c2cfa6b5',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '85d7dc88-9ed7-458a-b68c-f12a8231db1a'},
#   {'id': '9578c965-f13e-44d1-a04a-1c1ea24661b2',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '85d7dc88-9ed7-458a-b68c-f12a8231db1a'},
#   {'id': '3dc11084-d415-4f4d-848b-ddbc773578ea',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '7fa60682-6c92-4ce9-a698-a7c134325e4e'},
#   {'id': 'e105b2d4-c1c1-48b8-80f7-fc00b4dadec3',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '7fa60682-6c92-4ce9-a698-a7c134325e4e'},
#   {'id': 'f398f592-f272-4623-bb30-46a358bdf028',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '0ad21be0-8f2f-4517-99c0-8a7cb82fb6b6'},
#   {'id': '49fbcdad-e149-4aa5-bddd-0954705c39b1',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '0ad21be0-8f2f-4517-99c0-8a7cb82fb6b6'},
#   {'id': 'a0572033-f5cd-434a-89b5-2fb3b92ee95c',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '03c390d3-d13a-41f3-b33b-58769ec3e439'},
#   {'id': '56f53e1c-5063-42f5-8df0-0d9ae6f916b4',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '03c390d3-d13a-41f3-b33b-58769ec3e439'},
#   {'id': 'c7802c9b-de24-494c-acb9-ecd9418b28c2',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '76dfbad0-8935-4dc3-9081-cc8a6d81d2bf'},
#   {'id': 'c10a50a7-0146-4d98-9d66-a89c071cfebb',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '76dfbad0-8935-4dc3-9081-cc8a6d81d2bf'},
#   {'id': '15b93b6e-53cd-48f5-a4f6-51bed18e6a71',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'fa6a548a-1ebc-449d-b5f3-b4f3d8dd398a'},
#   {'id': '39c7b11a-4c1e-4592-b635-84dc8b9d970e',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'fa6a548a-1ebc-449d-b5f3-b4f3d8dd398a'},
#   {'id': 'c7fa2e97-46b8-44f9-9141-35d70b50dc6b',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': 'c491f9a3-6705-49ca-b9f9-4ed20b3188d0'},
#   {'id': '4424e8f0-9086-4894-8c8c-3def34f37ca7',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': 'c491f9a3-6705-49ca-b9f9-4ed20b3188d0'},
#   {'id': 'ddc85d44-37a2-4c07-a0d6-9b18bb8bc897',
#    'person_id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'party_id': 'par_us_1',
#    'constituency_id': '56e10156-ebc7-4f97-ba07-8e5c4d328303'},
#   {'id': '70045f36-39df-45ec-bc52-05abda5e9214',
#    'person_id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'party_id': 'par_us_2',
#    'constituency_id': '56e10156-ebc7-4f97-ba07-8e5c4d328303'}],
#  'persons': [{'id': '0ed5c4db-b222-431c-a71b-2de590179eeb',
#    'first_name': 'Ronna',
#    'middle_name': None,
#    'last_name': 'Romney McDaniel',
#    'known_name': 'Ronna McDaniel',
#    'title': None,
#    'gender': 'F',
#    'birthdate': None,
#    'mail': None,
#    'image': {'url': None, 'credit': {'photographer': None, 'agency': None}},
#    'uris': None},
#   {'id': '23096b62-9e83-46c5-b41e-453df6818668',
#    'first_name': 'Lynn',
#    'middle_name': None,
#    'last_name': 'Chapman',
#    'known_name': None,
#    'title': None,
#    'gender': 'F',
#    'birthdate': 'N/A',
#    'mail': 'N/A',
#    'image': {'url': None, 'credit': {'photographer': None, 'agency': None}},
#    'uris': None},
#   {'id': '2ee13050-e437-42a6-815e-420725cad26a',
#    'first_name': 'Jaime',
#    'middle_name': None,
#    'last_name': 'Harrison',
#    'known_name': None,
#    'title': None,
#    'gender': 'M',
#    'birthdate': None,
#    'mail': None,
#    'image': {'url': None, 'credit': {'photographer': None, 'agency': None}},
#    'uris': None},
#   {'id': '65ad7ddc-944e-4a09-bb2a-02adaca5fce3',
#    'first_name': 'Kamala',
#    'middle_name': 'Devi',
#    'last_name': 'Harris',
#    'known_name': None,
#    'title': None,
#    'gender': 'F',
#    'birthdate': '1964-10-20',
#    'mail': 'N/A',
#    'image': {'url': None, 'credit': {'photographer': None, 'agency': None}},
#    'uris': {'socials': [{'uri': 'https://www.instagram.com/kamalaharris',
#       'type': 'instagram',
#       'note': 'personal'},
#      {'uri': 'https://www.facebook.com/KamalaHarris',
#       'type': 'facebook',
#       'note': 'personal_page'},
#      {'uri': 'https://www.youtube.com/channel/UC0XBsJpPhOLg0k4x9ZwrWzw',
#       'type': 'youtube',
#       'note': 'personal'},
#      {'uri': 'https://twitter.com/KamalaHarris',
#       'type': 'twitter',
#       'note': 'personal'}],
#     'websites': [],
#     'wikipedia': [{'uri': 'https://en.wikipedia.org/wiki/Kamala_Harris',
#       'language': 'en-US'}]}},
#   {'id': '8dcb2404-b0eb-4812-a9dd-3b0d5ca96922',
#    'first_name': 'Janine',
#    'middle_name': None,
#    'last_name': 'Hansen',
#    'known_name': None,
#    'title': None,
#    'gender': 'F',
#    'birthdate': 'N/A',
#    'mail': 'N/A',
#    'image': {'url': 'N/A', 'credit': {'photographer': 'N', 'agency': 'A'}},
#    'uris': None},
#   {'id': 'b7d9f7a7-cbd4-4fa0-9edb-8c34ca884020',
#    'first_name': 'Virginia',
#    'middle_name': None,
#    'last_name': 'McGregor',
#    'known_name': None,
#    'title': None,
#    'gender': 'F',
#    'birthdate': None,
#    'mail': None,
#    'image': {'url': None, 'credit': {'photographer': None, 'agency': None}},
#    'uris': None},
#   {'id': 'fe410528-c88a-4297-a91d-10ac4d953371',
#    'first_name': 'Donald',
#    'middle_name': 'John',
#    'last_name': 'Trump',
#    'known_name': 'Donald Trump',
#    'title': None,
#    'gender': 'M',
#    'birthdate': '1946-06-14',
#    'mail': 'N/A',
#    'image': {'url': None, 'credit': {'photographer': None, 'agency': None}},
#    'uris': {'socials': [{'uri': 'https://www.facebook.com/DonaldTrump/',
#       'type': 'facebook',
#       'note': 'personal_page'},
#      {'uri': 'https://twitter.com/realDonaldTrump',
#       'type': 'twitter',
#       'note': 'personal'},
#      {'uri': 'https://www.instagram.com/realdonaldtrump/',
#       'type': 'instagram',
#       'note': 'personal'},
#      {'uri': 'https://www.youtube.com/channel/UCAql2DyGU2un1Ei2nMYsqOA',
#       'type': 'youtube',
#       'note': 'personal'}],
#     'websites': [{'uri': 'https://www.donaldjtrump.com/', 'note': 'personal'}],
#     'wikipedia': [{'uri': 'https://en.wikipedia.org/wiki/Donald_Trump',
#       'language': 'en-US'}]}}]}

# %%
results_per_constituency = data['election']['contest'][0]['results_per_constituency']
constituencies_data = data['constituencies']

# Create a dictionary to map constituency_id to name
constituency_id_to_name = {}
for constituency in constituencies_data:
    constituency_id = constituency['id']
    constituency_id_to_name[constituency_id] = constituency['name']

# Create lists to store the data for our DataFrame
ids = []
names = []

# Iterate through results_per_constituency
for result in results_per_constituency:
    constituency_id = result['constituency_id']
    ids.append(constituency_id)
    
    # Get the name from our mapping, or use 'Unknown' if not found
    name = constituency_id_to_name.get(constituency_id, 'Unknown')
    names.append(name)

# Create the DataFrame
constituencies_df = pd.DataFrame({
    'id': ids,
    'name': names
})

# Verify the length of the DataFrame
print(f"Number of rows in df_constituencies: {len(constituencies_df)}")
# Out:
# Number of rows in df_constituencies: 51

# %%
results = data['election']['contest'][0]['results_per_constituency']
results_df = pd.DataFrame(columns=['state', 'trump_score', 'harris_score', 'position', 'seats', 'type'])

for result in results:
    constituency_id = result['constituency_id']
    state_name = constituencies_df.loc[constituencies_df['id'] == constituency_id, 'name'].iloc[0]
    
    trump_score = 0
    harris_score = 0
    position = ''
    seats = 0
    
    # Extract the type from the result
    result_type = result['latest']['type']
    
    for candidate_result in result['latest']['results']:
        target_id = candidate_result['target_id']
        score = candidate_result['percent'][0]['value']['absolute']

        if candidate_result['seats']:
            seats = candidate_result['seats'].get('absolute', 0)
        
        # Find the corresponding candidate
        candidate = next((c for c in data['candidates'] if c['id'] == target_id), None)
        if candidate:
            person_id = candidate['person_id']
            
            # Find the corresponding person
            person = next((p for p in data['persons'] if p['id'] == person_id), None)
            if person:
                name = f"{person['first_name']} {person['last_name']}"
                if 'Donald Trump' in name:
                    trump_score = score
                elif 'Kamala Harris' in name:
                    harris_score = score
    
    score_difference = abs(harris_score - trump_score)
    if score_difference < 6:
        position = 'battleground'
    elif result_type == 'preliminary':
        position = 'democrat' if harris_score > trump_score else 'republican'
    elif result_type == 'trend':
        position = 'lean_harris' if harris_score > trump_score else 'lean_trump'
    else:
        position = 'unknown'
    
    # Add the data to results_df
    new_row = pd.DataFrame({
        'state': [state_name],
        'trump_score': [trump_score],
        'harris_score': [harris_score],
        'position': [position],
        'seats': [seats],
        'type': [result_type]  # Add the type to the new row
    })
    
    results_df = pd.concat([results_df, new_row], ignore_index=True)

results_df.to_csv("dpa_map_data.csv", index=False)
# Out:
# /var/folders/c8/bvk5bjs15mzg5h8m_jcbywx40000gn/T/ipykernel_58078/253741574.py:57: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)

# %%
electoral_votes = {
    'arizona': 11, 'california': 54, 'georgia': 16, 'florida': 30, 'maryland': 10,
    'michigan': 15, 'minnesota': 10, 'missouri': 10, 'montana': 4, 'nevada': 6,
    'new_mexico': 5, 'new_york': 28, 'north_carolina': 16, 'pennsylvania': 19,
    'texas': 40, 'virginia': 13, 'wisconsin': 10,
    'alabama': 9, 'alaska': 3, 'arkansas': 6, 'colorado': 10, 'connecticut': 7,
    'delaware': 3, 'hawaii': 4, 'idaho': 4, 'illinois': 19, 'indiana': 11,
    'iowa': 6, 'kansas': 6, 'kentucky': 8, 'louisiana': 8, 'maine': 4,
    'massachusetts': 11, 'mississippi': 6, 'nebraska': 5, 'new_hampshire': 4,
    'new_jersey': 14, 'north_dakota': 3, 'ohio': 17, 'oklahoma': 7, 'oregon': 8,
    'rhode_island': 4, 'south_carolina': 9, 'south_dakota': 3, 'tennessee': 11,
    'utah': 6, 'vermont': 3, 'washington': 12, 'washington_dc': 3, 'west_virginia': 4,
    'wyoming': 3
}

republican_seats = results_df[results_df['position'] == 'republican']['seats'].sum()
democrat_seats = results_df[results_df['position'] == 'democrat']['seats'].sum()

lean_harris_states = results_df[results_df['position'] == 'lean_harris']['state'].tolist()
lean_trump_states = results_df[results_df['position'] == 'lean_trump']['state'].tolist()
battleground_states = results_df[results_df['position'] == 'battleground']['state'].tolist()

lean_harris_votes = sum(electoral_votes.get(state.lower().replace(' ', '_'), 0) for state in lean_harris_states)
lean_trump_votes = sum(electoral_votes.get(state.lower().replace(' ', '_'), 0) for state in lean_trump_states)
battleground_votes = sum(electoral_votes.get(state.lower().replace(' ', '_'), 0) for state in battleground_states)

widget_df = pd.DataFrame({
    'republican': [republican_seats],
    'democrat': [democrat_seats],
    'lean_harris': [lean_harris_votes],
    'lean_trump': [lean_trump_votes],
    'battleground': [battleground_votes]
})

widget_df.to_csv("dpa_widget.csv", index=False)

# %%
swing_states = ['michigan', 'wisconsin', 'pennsylvania', 'nevada', 'arizona', 'north_carolina', 'georgia']

def update_state_data(state, results_row):
    # Read existing CSV
    csv_name = f"dpa_{state.lower().replace(' ', '_')}.csv"
    df = pd.read_csv(csv_name, parse_dates=['date'])
    
    # Create new row as a DataFrame
    new_row = pd.DataFrame({
        'date': [datetime.now()],
        'trump_score': [results_row['trump_score']],
        'harris_score': [results_row['harris_score']],
        'candidate_lead': ['harris' if results_row['harris_score'] > results_row['trump_score'] else 'trump'],
        'position': [results_row['position']]
    })
    
    # Concatenate new row to existing DataFrame
    df = pd.concat([df, new_row], ignore_index=True)
    
    # Export updated DataFrame to CSV
    df.to_csv(csv_name, index=False)
    print(f"Updated {csv_name}")

# Function to normalize state names
def normalize_state_name(name):
    return name.lower().replace(' ', '_')

# Main update function
def update_swing_state_data(results_df):
    # Normalize state names in results_df
    results_df['normalized_state'] = results_df['state'].apply(normalize_state_name)
    
    for state in swing_states:
        # Find the corresponding row in results_df
        state_data = results_df[results_df['normalized_state'] == normalize_state_name(state)]
        
        if not state_data.empty:
            update_state_data(state, state_data.iloc[0])
        else:
            print(f"No data found for {state} in results_df")

# Assuming results_df is updated every 5 minutes, you would call this function:
update_swing_state_data(results_df)
# Out:
# Updated dpa_michigan.csv
# Updated dpa_wisconsin.csv
# Updated dpa_pennsylvania.csv
# Updated dpa_nevada.csv
# Updated dpa_arizona.csv
# Updated dpa_north_carolina.csv
# Updated dpa_georgia.csv

# %%
# erase and re-create all csvs
# columns = ['date', 'trump_score', 'harris_score', 'candidate_lead', 'position']

# # Function to reset CSV files
# def reset_csv_files():
#     for state in swing_states:
#         filename = f"dpa_{state.lower().replace(' ', '_')}.csv"
#         # Remove existing file if it exists
#         if os.path.exists(filename):
#             os.remove(filename)
#         # Create new empty CSV file
#         df = pd.DataFrame(columns=columns)
#         df.to_csv(filename, index=False)
#         print(f"Reset and created empty CSV file: {filename}")

# reset_csv_files()

# %%
# # Search for state
# results = data['election']['contest'][0]['results_per_constituency']

# for result in results:
#     constituency_id = result['constituency_id']
#     state_name = constituencies_df.loc[constituencies_df['id'] == constituency_id, 'name'].iloc[0]
    
#     if state_name.lower() == 'delaware':
#         print("Delaware Results:")
#         print(result)
#         break
# else:
#     print("Delaware not found in the results.")
